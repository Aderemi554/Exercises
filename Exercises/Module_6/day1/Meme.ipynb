# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
image = '/Users/aderemifayoyiwa/Downloads/ComputerVision/mem_image2.jpg'
image = cv2.imread(image)
image_copy = image.copy()

# %%
image_copy = cv2.cvtColor(image_copy, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(10,5))
plt.imshow(image_copy);

# %%
green = 0,255,0
img = cv2.rectangle(image_copy, (100,660), (1200,720), green, -1)

# %%
red = 255,0,0
img_text = cv2.putText(img, 'Kaggle, can I have more GPU allocation?', (120,705), cv2.FONT_HERSHEY_DUPLEX, 1.6, red, 4 )

# %%
plt.figure(figsize=(10,5))
plt.imshow(img);

# %%
img = cv2.cvtColor(image_copy, cv2.COLOR_RGB2BGR)

# %%
cv2.imwrite('/Users/aderemifayoyiwa/Downloads/ComputerVision/meme1.jpg', img)
# Out:
# True
