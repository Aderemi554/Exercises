# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt


'''- best 50 are mostly animated
- 


rating by gross earning 
actors 
use octoparse 
title, gross, rating, actors (by year)

actors from previous animated films (all)

development of comedy gross 
'''

#Link to highest earning animated movies in the past 20 years
#https://www.imdb.com/search/title/?release_date=2000-01-01,2020-12-18&genres=animation&sort=boxoffice_gross_us,desc
# Out:
# '- best 50 are mostly animated\n- \n\n\nrating by gross earning \nactors \nuse octoparse \ntitle, gross, rating, actors (by year)\n\nactors from previous animated films (all)\n\ndevelopment of comedy gross \n'

# %%
Slides()

Graphs

What are the best comedy movies? Why
Which are the best comedy actors? Why
What should we do next?

timeseries/ gross income
line graph 
budget vs gross income
actors /movies (dot plot)


dataframe1 = read_csv()
dataframe2 = pd.read_csv()

# %%
imdb = pd.read_csv("/work/Top50_paramount_comedy-eng.csv")
imdb
imdb = imdb[["Title", "Year","Content","Content1","Content3","Content5","Content7", "Content9", "Number10"]]
imdb
#get_list = imdb['Field1_Link'].tolist()
#content = imbd['Content']
imdb1 = imdb[['Title','Number10']]


imdb1['Number10'] = imdb1['Number10'].str.replace('$', '')
imdb1['Number10'] = imdb1['Number10'].str.replace('M', '')
imdb1['Number10'] = imdb1['Number10'].astype('float')
print(imdb1.head(30))
# Out:
#                            Title  Number10
# 0                Shrek the Third    320.71
# 1                  Despicable Me    251.51
# 2                 Bruce Almighty    242.83
# 3              Shreck Ever After    238.37
# 4             Beverly Hills Cop     234.76
# 5                            Ted    218.82
# 6                   Madagascar 3    216.39
# 7                  Kung Fu Panda    215.43
# 8            Monsters vs. Aliens    198.35
# 9                     Madagascar    193.60
# 10  Teenage Mutant Ninja Turtles    191.20
# 11                Men in Black 2    190.42
# 12               What Women want    182.81
# 13                  Madagascar 2    180.01
# 14              Crocodile Dundee    174.64
# 15                   Bridesmaids    169.11
# 16               Kung Fu Panda 2    165.25
# 17                     Big Daddy    163.48
# 18         SpongeBob Squarepants    162.99
# 19                      The Heat    159.58
# 20              The Longest Yard    158.12
# 21               Over the Headge    155.02
# 22          Beverly Hills Cop II    153.67
# 23                 Runaway Bride    152.26
# 24                 Daddy's Home     150.36
# 25                Puss in Boots     149.26
# 26                      Megamind    148.42
# 27               Little Fockers     148.38
# 28            Sonic The Hedgehog    146.07
# 29                   Rush Hour 3    140.13
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /shared-libs/python3.7/py-core/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':

# %%
plt.plot(imdb1['Title'], imdb1['Number10'], 'o', color='red')

# %%
print(imdb['Title'])
# Out:
# 0                                      Shrek der Dritte
# 1                         Ich - Einfach unverbesserlich
# 2                                      Bruce Allmächtig
# 3                                       Für immer Shrek
# 4     Beverly Hills Cop - Ich lös' den Fall auf jede...
# 5                                                   Ted
# 6                     Madagascar 3: Flucht durch Europa
# 7                                         Kung Fu Panda
# 8                                   Monsters vs. Aliens
# 9                                            Madagascar
# 10                         Teenage Mutant Ninja Turtles
# 11                                       Men in Black 2
# 12                                    Was Frauen wollen
# 13                                         Madagascar 2
# 14           Crocodile Dundee - Ein Krokodil zum Küssen
# 15                                           Brautalarm
# 16                                      Kung Fu Panda 2
# 17                                            Big Daddy
# 18        SpongeBob Schwammkopf: Schwamm aus dem Wasser
# 19                                         Taffe Mädels
# 20                                    Spiel ohne Regeln
# 21                                   Ab durch die Hecke
# 22                                 Beverly Hills Cop II
# 23                      Die Braut, die sich nicht traut
# 24                     Daddy's Home - Ein Vater zu viel
# 25                                Der gestiefelte Kater
# 26                                             Megamind
# 27                    Meine Frau, unsere Kinder und ich
# 28                                   Sonic The Hedgehog
# 29                                          Rush Hour 3
# 30                                      Himmel und Huhn
# 31                                Der Prinz aus Zamunda
# 32                 Anchorman - Die Legende kehrt zurück
# 33                        Bee Movie - Das Honigkomplott
# 34                                      Die Truman Show
# 35                                                Rango
# 36                                        Wayne's World
# 37              Lemony Snicket - Rätselhafte Ereignisse
# 38                                       Die Eisprinzen
# 39                             Zurück in die Zukunft II
# 40                                    Die Addams Family
# 41                                        Der Babynator
# 42                                       Tropic Thunder
# 43                                         Valentinstag
# 44                Star Trek IV: Zurück in die Gegenwart
# 45                                   Crocodile Dundee 2
# 46                                Zeit der Zärtlichkeit
# 47                    Wie werde ich ihn los in 10 Tagen
# 48                             Der Club der Teufelinnen
# 49                               Der Kindergarten Daddy
# Name: Title, dtype: object
